# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv(r"E:\flipo\cutomer_retention.csv")

# %%
data
# Out:
#     1Gender of respondent 2 How old are you?   \
# 0                    Male         31-40 years
# 1                  Female         21-30 years
# 2                  Female         21-30 years
# 3                    Male         21-30 years
# 4                  Female         21-30 years
# ..                    ...                 ...
# 264                Female         21-30 years
# 265                Female         31-40 years
# 266                Female         41-50 yaers
# 267                Female  Less than 20 years
# 268                Female         41-50 yaers
#
#     3 Which city do you shop online from?  \
# 0                                   Delhi
# 1                                   Delhi
# 2                           Greater Noida
# 3                                 Karnal
# 4                              Bangalore
# ..                                    ...
# 264                                 Solan
# 265                             Ghaziabad
# ...

# %%
# check categorical column
for column in data.columns:
    if data[column].dtype==object:
        print(str(column)+ " : "+str(data[column].unique()))
        print(data[column].value_counts())
        print('-------------------------------------')
# Out:
# 1Gender of respondent : ['Male' 'Female']
# Female    181
# Male       88
# Name: 1Gender of respondent, dtype: int64
# -------------------------------------
# 2 How old are you?  : ['31-40 years' '21-30 years' '41-50 yaers' 'Less than 20 years'
#  '51 years and above']
# 31-40 years           81
# 21-30 years           79
# 41-50 yaers           70
# Less than 20 years    20
# 51 years and above    19
# Name: 2 How old are you? , dtype: int64
# -------------------------------------
# 3 Which city do you shop online from? : ['Delhi' 'Greater Noida' 'Karnal ' 'Bangalore ' 'Noida' 'Solan'
#  'Moradabad' 'Gurgaon ' 'Merrut' 'Ghaziabad' 'Bulandshahr']
# Delhi            58
# Greater Noida    43
# Noida            40
# Bangalore        37
# Karnal           27
# Solan            18
# Ghaziabad        18
# Gurgaon          12
# Merrut            9
# Moradabad         5
# Bulandshahr       2
# Name: 3 Which city do you shop online from?, dtype: int64
# -------------------------------------
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 269 entries, 0 to 268
# Data columns (total 71 columns):
#  #   Column                                                                                                                                                                                                          Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                          --------------  -----
#  0   1Gender of respondent                                                                                                                                                                                           269 non-null    object
# ...

# %%
sns.countplot(data["1Gender of respondent"])
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.countplot(data[data.columns[1]])
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.countplot(data["3 Which city do you shop online from?"])
plt.show()

# %%
sns.countplot(data["5 Since How Long You are Shopping Online ?"])
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.countplot(data["6 How many times you have made an online purchase in the past 1 year?"])
plt.show()

# %%
sns.countplot(data["7 How do you access the internet while shopping on-line?"])
plt.show()

# %%
sns.countplot(data["8 Which device do you use to access the online shopping?"])
plt.show()

# %%
sns.countplot(data[data.columns[10]])
plt.show()

# %%
sns.countplot(data[data.columns[11]])
plt.show()

# %%
sns.countplot(data[data.columns[12]])
plt.show()

# %%
plt.figure(figsize=(8,8))
sns.countplot(data[data.columns[13]])
plt.show()

# %%
plt.figure(figsize=(8,8))
sns.countplot(data[data.columns[14]])
plt.show()

# %%
sns.countplot(data[data.columns[15]])
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.countplot(data["18 The content on the website must be easy to read and understand"])
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.countplot(data["18 The content on the website must be easy to read and understand"])
plt.show()

# %%
sns.countplot(data["19 Information on similar product to the one highlighted  is important for product comparison"])
plt.show()

# %%
plt.figure(figsize=(8,8))
sns.countplot(data["20 Complete information on listed seller and product being offered is important for purchase decision."])
plt.show()

# %%
plt.figure(figsize=(8,8))
sns.countplot(data["21 All relevant information on listed products must be stated clearly"])
plt.show()

# %%
plt.figure(figsize=(8,8))
sns.countplot(data["22 Ease of navigation in website"])
plt.show()

# %%
plt.figure(figsize=(8,8))
sns.countplot(data["23 Loading and processing speed"])
plt.show()

# %%
plt.figure(figsize=(8,8))
sns.countplot(data["24 User friendly Interface of the website"])
plt.show()

# %%
sns.countplot(data["25 Convenient Payment methods"])
plt.show()

# %%
sns.countplot(data["26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time"])
plt.show()

# %%
sns.countplot(data["28 Being able to guarantee the privacy of the customer"])
plt.show()

# %%
sns.countplot(data["29 Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.)"])
plt.show()

# %%
plt.figure(figsize=(8,8))
sns.countplot(data["30 Online shopping gives monetary benefit and discounts"])
plt.show()

# %%
plt.figure(figsize=(8,8))
sns.countplot(data["31 Enjoyment is derived from shopping online"])
plt.show()

# %%
plt.figure(figsize=(8,8))
sns.countplot(data["32 Shopping online is convenient and flexible"])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.countplot(data["33 Return and replacement policy of the e-tailer is important for purchase decision"])
plt.show()

# %%
plt.figure(figsize=(8,8))
sns.countplot(data["34 Gaining access to loyalty programs is a benefit of shopping online"])
plt.show()

# %%
plt.figure(figsize=(8,8))
sns.countplot(data["35 Displaying quality Information on the website improves satisfaction of customers"])
plt.show()

# %%
sns.countplot(data["36 User derive satisfaction while shopping on a good quality website or application"])
plt.show()

# %%
sns.countplot(data["37 Net Benefit derived from shopping online can lead to users satisfaction"])
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.countplot(data["38 User satisfaction cannot exist without trust"])
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.countplot(data["39 Offering a wide variety of listed product in several category"])
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.countplot(data["40 Provision of complete and relevant product information"])
plt.show()

# %%
sns.countplot(data["41 Monetary savings"])
plt.show()

# %%
sns.countplot(data["42 The Convenience of patronizing the online retailer"])
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.countplot(data["43 Shopping on the website gives you the sense of adventure"])
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.countplot(data["44 Shopping on your preferred e-tailer enhances your social status"])
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.countplot(data["45 You feel gratification shopping on your favorite e-tailer"])
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.countplot(data["46 Shopping on the website helps you fulfill certain roles"])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.countplot(data["47 Getting value for money spent"])
plt.show()

# %%
plt.figure(figsize=(25,25))
sns.countplot(data["Easy to use website or application"])
plt.show()

# %%
plt.figure(figsize=(30,15))
sns.countplot(data["Visual appealing web-page layout"])
plt.show()

# %%
plt.figure(figsize=(30,15))
sns.countplot(data["Wild variety of product on offer"])
plt.show()

# %%
plt.figure(figsize=(30,15))
sns.countplot(data["Complete, relevant description information of products"])
plt.show()

# %%
plt.figure(figsize=(30,15))
sns.countplot(data["Fast loading website speed of website and application"])
plt.show()

# %%
plt.figure(figsize=(30,15))
sns.countplot(data["Reliability of the website or application"])
plt.show()

# %%
plt.figure(figsize=(30,15))
sns.countplot(data["Quickness to complete purchase"])
plt.show()

# %%
plt.figure(figsize=(30,15))
sns.countplot(data["Availability of several payment options"])
plt.show()

# %%
plt.figure(figsize=(30,15))
sns.countplot(data[data.columns[55]])
plt.show()

# %%
plt.figure(figsize=(30,15))
sns.countplot(data["Privacy of customers� information"])
plt.show()

# %%
plt.figure(figsize=(30,15))
sns.countplot(data["Security of customer financial information"])
plt.show()

# %%
plt.figure(figsize=(30,15))
sns.countplot(data["Perceived Trustworthiness"])
plt.show()

# %%
plt.figure(figsize=(30,15))
sns.countplot(data["Longer time to get logged in (promotion, sales period)"])
plt.show()

# %%
plt.figure(figsize=(30,15))
sns.countplot(data["Longer time in displaying graphics and photos (promotion, sales period)"])
plt.show()

# %%
plt.figure(figsize=(30,15))
sns.countplot(data["Late declaration of price (promotion, sales period)"])
plt.show()

# %%
plt.figure(figsize=(30,15))
sns.countplot(data["Longer page loading time (promotion, sales period)"])
plt.show()

# %%
plt.figure(figsize=(30,15))
sns.countplot(data["Limited mode of payment on most products (promotion, sales period)"])
plt.show()

# %%
plt.figure(figsize=(30,15))
sns.countplot(data["Longer delivery period"])
plt.show()

# %%
plt.figure(figsize=(30,15))
sns.countplot(data["Longer delivery period"])
plt.show()

# %%
plt.figure(figsize=(30,15))
sns.countplot(data["Change in website/Application design"])
plt.show()

# %%
plt.figure(figsize=(30,15))
sns.countplot(data["Frequent disruption when moving from one page to another"])
plt.show()

# %%
plt.figure(figsize=(30,15))
sns.countplot(data["Website is as efficient as before"])
plt.show()

# %%
plt.figure(figsize=(30,15))
sns.countplot(data["Which of the Indian online retailer would you recommend to a friend?"])
plt.show()

# %%
#Findings
#1 female shops online more than men
#2 age group of 21-40 years shop online more than any other age group.
#3 Large no of people who shop online belongs to Delhi location.
#4 98 people are shopping online for more than 4 years
#5 more than 62 people shopped online 31-40 times and more than 115 people shopped online less than 10 times in a year.
#6 maximum no of people shop online through mobile internet.
#7 More than 200 people use google chrome for surfing the internet.
#8 more than 120 people takes more than 15 mins to take purchase decision.
#9 more than 140 people prefer debit or credit card for payments option.
#10 more than 160 people rarely abondon purchase decision.
#11 160 people strongly agree with the easy and understanding content on website.
#12 more than 120 people agree with the all relevent information must be stated clearly.
#13 approx. 140 people strongly agree with the Ease of navigation in website.
#14 approx more than 110 people strongly with the Loading and processing speed of website.
#15 approx more than 175 people strongly agree with User friendly Interface of the website.
#16 approx 150 people strongly agree with the Convenient Payment methods.
#17 approx 175 people strongly agree with the being able to guarantee the privacy of the customer.
#18 approx 100 people strongly agree with the Online shopping gives monetary benefit and discounts.
#19 approx 80 people strongly agree with the Enjoyment is derived from shopping online.
#20 majority of the people approx 190 people strongly agree with the Return and replacement policy of the e-tailer is important for purchase decision.
#21 majority of the people approx 120 people strongly agree with the Displaying quality Information on the website improves satisfaction of customers
#22 majority of the people approx 160 people strongly agree with the Net Benefit derived from shopping online can lead to users satisfaction.
#23 majority of the people approx 140 people strongly agree with the Monetary savings.
#24 majority of the people approx 140 people strongly agree with the Getting value for money spent.
#25 majority of the people approx 120 people strongly agree with the Wild variety of product on offer.
#26 majority of the people approx 100 people strongly supports amazon and flipkart website for the Complete, relevant description information of products.
#27 majority of the people approx 60 people strongly supports amazon for the Reliability of the website or application.
#28 majority of the people approx 60 people strongly supports amazon and flipkart for Availability of several payment options.
#29 majority of the people approx 60 people strongly supports amazon for Privacy of customers� information.
#30 majority of the people approx 60 people strongly supports amazon for Security of customer financial information.
#31 majority of the people approx 60 people are not happy with the Amazon and flipkart for Longer time in displaying graphics and photos (promotion, sales period) amazon
#32 majority of the people approx 70 people are not happy with the Myntra for Late declaration of price (promotion, sales period.
#33 majority of the people approx 80 people are not happy with the Snapdeal for Limited mode of payment on most products (promotion, sales period.
#34 majority of the people approx 70 people are not happy with the Snapdeal for Longer delivery period.
#35 majority of the people approx 70 people are not happy with the Amazon and Myntra for Frequent disruption when moving from one page to another.
#36 majority of the people approx 75 people recommended the Indian online retailer Amazon for shopping.

# %%
#Conclusion
#1. More and more products should be displayed keeping in mind the age group of 20-41 years as this age group shop online more than any age group.
#2. More and more promotion of online purchase should be done to encourage for online shopping.
#3. google chrome is the most famous browers among online shoppers.
#4. facility of debit and credit card payments should be available as it is one of the prefered payment option amongst the online shoppers.
#5. Content on website should be design in such a way that it should be easy to understand for the online  shoppers.
#6. Privacy of the customer should be taken care.
#7. More and more discount and monetary benefits should be given to attract online shoppers.
#8. Return and replacement policy of the e-tailer is important for purchase decision so Return and replacement policy should be made flexible.
#9. Quality products should be given to buyers at reasonable price.
#10.variety of products should be available on online retailer websites to attract customers.
#11.Most of the people trust amazon and flipkart website for the Complete, relevant description information of products.
#12.Most of the people trust amazon Reliability of the website or application.
#13.Most of the people use amazon and flipkart for Availability of several payment options.
#14.Most of the people use amazon for Privacy of customers� information.
#15.Most of the people use amazon for Security of customer financial information.
#16.Online retailer websites should not take longer time in displaying graphics and photos.
#17.Online retailer websites should not take Late declaration of price (promotion, sales period).
#18.Online retailer websites should not take Longer delivery period.
#19.Online retailer websites should not provide Limited mode of payment on most products.
#20.Online retailer websites should not get Frequent disruption when moving from one page to another.
#All these factors should be taken care to provide full satisfaction to customer to retained its customers.
